# %%
import skimage as ski

image = ski.data.coins()

# %%
ski.io.imshow(image)
ski.io.show()
# Out:
# <ipython-input-7-7a6f7ce19235>:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(image)
# <ipython-input-7-7a6f7ce19235>:2: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.show()

# %%
# ... or any other NumPy array!
edges = ski.filters.sobel(image)
ski.io.imshow(edges)
ski.io.show()
# Out:
# <ipython-input-8-82efa82a0b40>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(edges)
# <ipython-input-8-82efa82a0b40>:4: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.show()

# %%
from skimage.exposure import histogram
coins = ski.data.coins()
hist, hist_centers = ski.exposure.histogram(coins)

# %%
edges = ski.feature.canny(coins / 255.)

# %%
import scipy as sp
fill_coins = sp.ndimage.binary_fill_holes(edges)
